# %%
import pandas as pd
import json
import numpy as np

# %%
df = pd.read_csv('exo-archive.csv')
df.head()
# Out:
#       pl_name  hostname  sy_snum  sy_pnum  discoverymethod  disc_year  \
# 0    11 Com b    11 Com        2        1  Radial Velocity       2007
# 1    11 UMi b    11 UMi        1        1  Radial Velocity       2009
# 2    14 And b    14 And        1        1  Radial Velocity       2008
# 3    14 Her b    14 Her        1        2  Radial Velocity       2002
# 4  16 Cyg B b  16 Cyg B        3        1  Radial Velocity       1996
#
#                             disc_facility  pl_controv_flag   pl_orbper  \
# 0                        Xinglong Station                0   323.21000
# 1  Thueringer Landessternwarte Tautenburg                0   516.21997
# 2       Okayama Astrophysical Observatory                0   186.76000
# 3                  W. M. Keck Observatory                0  1765.03890
# 4                  Multiple Observatories                0   798.50000
#
#    pl_orbpererr1  ...  sy_disterr2  sy_vmag  sy_vmagerr1  sy_vmagerr2  \
# ...

# %%
df['dec'], df['ra']
# Out:
# (0       17.793252
#  1       71.823943
#  2       39.235837
#  3       43.816362
#  4       50.516824
#            ...
#  5760    41.403815
#  5761    41.403815
#  5762    41.403815
#  5763    -0.823564
#  5764     8.461105
#  Name: dec, Length: 5765, dtype: float64,
#  0       185.178779
#  1       229.274595
#  2       352.824150
#  3       242.602101
#  4       295.465642
#             ...
#  5760     24.198353
#  5761     24.198353
#  5762     24.198353
#  5763    174.237219
#  5764    298.562449
#  Name: ra, Length: 5765, dtype: float64)

# %%
df['dec_radians'] = df['dec']*np.pi/180
df['ra_radians'] = np.pi/2 - df['ra']*np.pi/180

# %%
df['dec_radians']
# Out:
# 0       0.310551
# 1       1.253564
# 2       0.684795
# 3       0.764740
# 4       0.881685
#           ...
# 5760    0.722633
# 5761    0.722633
# 5762    0.722633
# 5763   -0.014374
# 5764    0.147674
# Name: dec_radians, Length: 5765, dtype: float64

# %%
df.to_json('exoplanets.json')
